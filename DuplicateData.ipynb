# %% [markdown]
# Dealing with Duplicate values

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv("googleplaystore.csv")
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df= data.copy()

# %%
#checking the total number of rows with duplicate values
df.duplicated().sum()
# Out:
# 483

# %%
df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Length: 10841, dtype: bool

# %%
#This gives me the rows that are having duplicate values
df[df.duplicated()]
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
#Ths gives the number of duplicate values in the particular column(Category)
df.duplicated('Category').sum()
# Out:
# 10324

# %%
df[df.duplicated(keep="first")]    #It will keep the first values and will show me the last value
# Out:
#                                                    App      Category  Rating  \
# 229                       Quick PDF Scanner + OCR FREE      BUSINESS     4.2
# 236                                                Box      BUSINESS     4.2
# 239                                 Google My Business      BUSINESS     4.4
# 256                                ZOOM Cloud Meetings      BUSINESS     4.4
# 261                          join.me - Simple Meetings      BUSINESS     4.0
# ...                                                ...           ...     ...
# 8643                    Wunderlist: To-Do List & Tasks  PRODUCTIVITY     4.6
# 8654   TickTick: To Do List with Reminder, Day Planner  PRODUCTIVITY     4.6
# 8658                           ColorNote Notepad Notes  PRODUCTIVITY     4.6
# 10049        Airway Ex - Intubate. Anesthetize. Train.       MEDICAL     4.3
# 10768                                             AAFP       MEDICAL     3.8
#
# ...

# %%
df[df.duplicated(keep="last")]   #It will keep all the last values and will show me the first values
# Out:
#                                 App             Category  Rating Reviews  \
# 164                    Ebook Reader  BOOKS_AND_REFERENCE     4.1   85842
# 192   Docs To Go™ Free Office Suite             BUSINESS     4.1  217730
# 193              Google My Business             BUSINESS     4.4   70991
# 204                             Box             BUSINESS     4.2  159872
# 213             ZOOM Cloud Meetings             BUSINESS     4.4   31614
# ...                             ...                  ...     ...     ...
# 3787     ABC News - US & World News   NEWS_AND_MAGAZINES     4.0   18976
# 3788                       NBC News   NEWS_AND_MAGAZINES     4.1   63020
# 3790                      USA TODAY   NEWS_AND_MAGAZINES     4.1   49259
# 3792   CNN Breaking US & World News   NEWS_AND_MAGAZINES     4.0  293080
# 3795   Newsroom: News Worth Sharing   NEWS_AND_MAGAZINES     4.2  201737
#
#                     Size     Installs  Type Price Content Rating  \
# ...

# %%
df[df.duplicated(keep=False)] #it will show all the values that are duplicate.
# Out:
#                                                    App             Category  \
# 164                                       Ebook Reader  BOOKS_AND_REFERENCE
# 192                      Docs To Go™ Free Office Suite             BUSINESS
# 193                                 Google My Business             BUSINESS
# 204                                                Box             BUSINESS
# 213                                ZOOM Cloud Meetings             BUSINESS
# ...                                                ...                  ...
# 8643                    Wunderlist: To-Do List & Tasks         PRODUCTIVITY
# 8654   TickTick: To Do List with Reminder, Day Planner         PRODUCTIVITY
# 8658                           ColorNote Notepad Notes         PRODUCTIVITY
# 10049        Airway Ex - Intubate. Anesthetize. Train.              MEDICAL
# 10768                                             AAFP              MEDICAL
#
# ...

# %% [markdown]
# Dropping the Duplicate Values

# %%
#Dropping all the values
df.drop_duplicates(inplace=True)
df
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df.shape
# Out:
# (10358, 13)

# %%
#For Example
cities = ['NY','LA','Chicago','HJouston','Pheonix','LA','Chicago']
Rankings = [1,2,3,4,5,6,7]
Scores = [9.8, 9.5, 9.2, 8.7, 8.5, 8.2, 8.1]
example = {'city': cities, 'Rank':Rankings, 'scores':Scores}

ex = pd.DataFrame(example)
ex
# Out:
#        city  Rank  scores
# 0        NY     1     9.8
# 1        LA     2     9.5
# 2   Chicago     3     9.2
# 3  HJouston     4     8.7
# 4   Pheonix     5     8.5
# 5        LA     6     8.2
# 6   Chicago     7     8.1

# %%
# Row 1 (LA, 2, 9.5) is not exactly the same as Row 5 (LA, 6, 8.2).

# Row 2 (Chicago, 3, 9.2) is not exactly the same as Row 6 (Chicago, 7, 8.1).

# Since no entire rows are identical, df.duplicated().sum() returns 0.

ex.duplicated().sum()
# Out:
# 0

# %%
ex[ex.duplicated()]
# Out:
# Empty DataFrame
# Columns: [city, Rank, scores]
# Index: []

# %%
#this gives the number of cities that are duplicate in the column 'city'
ex.duplicated('city').sum()
# Out:
# 2

# %%
#Droping the Duplicate cities
ex.drop_duplicates('city', keep ='first', inplace=True)
ex
# Out:
#        city  Rank  scores
# 0        NY     1     9.8
# 1        LA     2     9.5
# 2   Chicago     3     9.2
# 3  HJouston     4     8.7
# 4   Pheonix     5     8.5
